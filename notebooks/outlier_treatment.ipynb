# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/featured_data/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0         flats               rof ananda   sector 95   0.38            58.0
# 1         flats   breez global hill view  sohna road   0.35          6315.0
# 2         flats             tulip violet   sector 69   1.65          8872.0
# 3         house         suncity township   sector 54  25.00         31111.0
# 4         flats  shree vardhman victoria   sector 70   1.75          8974.0
#
#       area                        areaWithType  bedRoom  bathroom balcony  \
# 0  65517.0  Carpet area: 64412 (5984.07 sq.m.)        3         2       1
# 1    554.0   Carpet area: 554.16 (51.48 sq.m.)        2         2       2
# 2   1860.0   Built Up area: 1578 (146.6 sq.m.)        3         3       2
# 3   8036.0        Plot area 1000(836.13 sq.m.)        4         4      3+
# 4   1950.0  Built Up area: 1950 (181.16 sq.m.)        3         5       0
#
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 3597         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 1785         house                                        independent
# 1197         house                                     dlf city plots
# 1418         house                                        independent
# 3            house                                   suncity township
# 1876         house                             emaar the palm springs
# 2767         house                                        independent
# 3778         house                                 vipul tatvam villa
# 824          house                             luxury dlf city floors
# 229          house                                     dlf city plots
# 2170         house                                        independent
# 3405         house                                 vipul tatvam villa
# ...

# %% [markdown]
# ### price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\2451507319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
#peoblem in the data is that area is in sq ft above 1000 and in sq yards below 1000. thats why we haev to multiply the area by 9 to convert them to sq ft to get correct price per sq ft
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\1109903987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\356977414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft) #updating the original dataframe

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 924          house            cloudnine cottages  sohna road road   5.50
# 1125         house            emaar mgf marbella        sector 66  18.00
# 1197         house                dlf city plots        sector 26  26.00
# 1418         house                   independent        sector 26  26.00
# 1529         house                   independent        sector 25  16.00
# 1876         house        emaar the palm springs        sector 54  24.00
# 2206         house                  malibu towne        sector 47   8.50
# 2369         house  project housing board colony        sector 31   8.00
# 2461         flats                unitech vistas        sector 70   9.00
# 2977         house        emaar the palm springs        sector 54  14.00
# 3210         house                unitech escape        sector 50  10.80
# 3449         house                           nul        sector 28  12.50
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000] #prices are less even though the are a is large
# Out:
#      property_type                    society      sector  price  \
# 354          house                independent   sector 50   5.00
# 463          flats      signature the roselia   sector 95   0.45
# 882          flats          hcbs sports ville  sohna road   0.35
# 1687         flats  signature global solera 2  sector 107   0.51
# 3285         flats            ramsons kshitij   sector 95   0.31
#
#       price_per_sqft      area                           areaWithType  \
# 354            232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 463              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 882              4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 1687             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 3285             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 354         6         5      3+       2.0         NaN    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\4282079938.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 3279, 2258, 0, 1105, 2317, 3409, 910, 705, 666
# Out:
#      property_type                    society           sector  price  \
# 3279         house                independent        sector 26  18.40
# 325          house  ganpati heights apartment        sector 13   1.25
# 2258         flats                 rof ananda        sector 95   0.38
# 0            flats                 rof ananda        sector 95   0.38
# 2087         house      dlf city plot phase 4        sector 28  13.00
# 1105         flats              pyramid elite        sector 86   0.46
# 2317         flats                 rof ananda        sector 95   0.33
# 3409         flats      signature the serenas       sohna road   0.28
# 1756         house                independent        sector 25   7.30
# 910          flats            ramsons kshitij        sector 95   0.24
# 705          flats                 rof ananda        sector 95   0.21
# 674          house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[3279, 2258, 0, 1105, 2317, 3409, 910, 705, 666], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 325          house  ganpati heights apartment        sector 13   1.25
# 2087         house      dlf city plot phase 4        sector 28  13.00
# 1756         house                independent        sector 25   7.30
# 674          house                independent        sector 57   6.25
# 2968         house                independent        sector 43   5.50
# 573          flats                 godrej air        sector 85   2.50
# 3507         house       unitech aspen greens        sector 50   6.95
# 228          flats                godrej icon       sector 88a   1.75
# 1785         house                independent        sector 43  27.50
# 1284         flats             m3m golfestate        sector 65  13.20
# 2212         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 325            151.0  82781.0
# 2087          1992.0  65261.0
# 1756          1560.0  46795.0
# ...

# %%
df.loc[325,'area'] = 115*9
df.loc[2087,'area'] = 7250
df.loc[1756,'area'] = 5800
df.loc[674,'area'] = 2660
df.loc[2968,'area'] = 2850
df.loc[573,'area'] = 1812
df.loc[3507,'area'] = 2160
df.loc[228,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### beddroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 744          house                  independent   sector 54   5.00
# 524          house                  independent   sector 43   4.50
# 1414         house                  independent  sector 17a   3.87
# 2484         house                  independent  sector 17a   3.93
# 30           house                private house   sector 55   7.05
# 2936         house                  independent   sector 54   5.50
# 1114         house                  independent   sector 55   9.19
# 3374         house                  independent   sector 40  12.00
# 2075         house                  independent   sector 56  12.39
# 824          house       luxury dlf city floors   sector 26  20.00
# 229          house               dlf city plots   sector 26  20.00
# 285          house                  independent   sector 43  13.50
# 3686         house                  independent   sector 11   4.50
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3655         house  adani brahma samsara  sector 60  18.02         28200.0
# 1175         house           independent  sector 24  11.00         28902.0
# 2169         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 3655  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 1175  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 2169  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3655        12      3+       3.0  North-East  Relatively New
# 1175        11      3+       3.0        East    Old Property
# 2169        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#     property_type                      society       sector  price  \
# 435         flats  bestech park view grand spa    sector 81    4.7
# 789         flats       krrish provence estate  gwal pahari    7.5
#
#      price_per_sqft     area                             areaWithType  \
# 435          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 789          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#      bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 435        4         4      3+      19.0       North  Relatively New
# 789        5         6      3+      23.0  North-East  Relatively New
#
#      super_built_up_area  built_up_area  carpet_area  study room  \
# 435               6926.0            NaN          NaN           0
# 789              10000.0            NaN          NaN           0
#
#      servant room  store room  pooja room  others  furnishing_type  \
# 435             1           0           0       0                0
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %% [markdown]
# ### crapet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 573          flats      godrej air  sector 85    2.5          1379.0   1812.0
# 1284         flats  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 573   Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 1284  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 573   North-East       Undefined                  NaN            NaN
# 1284       North  Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 573       18122.0           1             0           0           1       1
# 1284      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[573,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1284         flats  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1284  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 1284  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 1284           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 1284                1            60

# %% [markdown]
# ### luxury score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 116          house                   independent   sector 25   13.0
# 538          house                   independent   sector 55    5.0
# 913          house  sushant lok 1 builder floors   sector 43   13.0
# 986          house                dlf city plots   sector 26   19.0
# 1509         house                   independent   sector 26   19.0
# 2170         house                   independent   sector 26   20.0
# 3082         house                   independent   sector 43    9.5
# 3520         house                   independent  sector 105    9.9
# 3692         house                   independent   sector 28   12.0
#
#       price_per_sqft    area  \
# 116          45710.0  2844.0
# 538          44444.0  1125.0
# 913          48148.0  2700.0
# 986          42054.0  4518.0
# 1509         42222.0  4500.0
# 2170         44444.0  4500.0
# 3082         42222.0  2250.0
# 3520         49500.0  2000.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(250.5)

# %%
df[(df['area']/df['bedRoom'])<250].shape
# Out:
# (185, 23)

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio']=df['area']/df['bedRoom']
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\2419531321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio']=df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     46
# 3     33
# 5      5
# 4      4
# 10     2
# 9      2
# 6      2
# 8      2
# Name: count, dtype: int64

# %%
df=df[df['area_room_ratio']>100]

# %%
outliers_df=df[(df['area_room_ratio']<250) & (df['bedRoom']>3)]

# %%
outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_6180\3359844150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio']= df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom'] > 4)].shape
# Out:
# (0, 24)

# %%
df= df[~((df['area_room_ratio']<250) & (df['bedRoom'] > 4))]

# %%
df.shape
# Out:
# (3555, 24)

# %%
import os
data_path=os.path.join('..','data','outlier_treated_data')
os.makedirs(data_path)
df.to_csv(os.path.join(data_path,'gurgaon_properties_outlier_treated.csv'),index=False)
